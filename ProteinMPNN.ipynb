# %% [markdown]
# <a href="https://colab.research.google.com/github/KhondamirRustamov/AF2seq/blob/main/ProteinMPNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title setup
# %%time
import os
if not os.path.isdir("params"):
  # get code
  os.system("pip -q install git+https://github.com/sokrypton/ColabDesign.git@v1.1.1")
  # for debugging
  os.system("ln -s /usr/local/lib/python3.*/dist-packages/colabdesign colabdesign")
  # download params
  os.system("mkdir params")
  os.system("apt-get install aria2 -qq")
  os.system("aria2c -q -x 16 https://storage.googleapis.com/alphafold/alphafold_params_2022-12-06.tar")
  os.system("tar -xf alphafold_params_2022-12-06.tar -C params")

os.system('''pip install "colabfold[alphafold] @ git+https://github.com/sokrypton/ColabFold"''')
#os.system('''pip install -q "jax[cuda]==0.3.25" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html''')
#pip install -q "jax[cuda]==0.3.25" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import os
from colabdesign import mk_afdesign_model, clear_mem
from IPython.display import HTML
from google.colab import files
import numpy as np
# Out:
# CPU times: user 1.62 s, sys: 391 ms, total: 2.01 s
# Wall time: 2min 35s

# %%
#@title setup1
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:09
# 🔁 Restarting kernel...

# %%
#@title setup1.1
# !mamba install openmm==7.7.0 pdbfixer -c conda-forge
# Out:
# Looking for: ['openmm==7.7.0', 'pdbfixer']
#
# [+] 0.0s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.2s
# conda-forge/linux-64   2%
# conda-forge/noarch     1%[+] 0.3s
# conda-forge/linux-64   6%
# conda-forge/noarch    28%[+] 0.4s
# conda-forge/linux-64  16%
# conda-forge/noarch    39%[+] 0.5s
# conda-forge/linux-64  21%
# conda-forge/noarch    50%[+] 0.6s
# conda-forge/linux-64  21%
# conda-forge/noarch    62%[+] 0.7s
# conda-forge/linux-64  26%
# conda-forge/noarch    62%[+] 0.8s
# conda-forge/linux-64  26%
# conda-forge/noarch    73%[+] 0.9s
# conda-forge/linux-64  26%
# conda-forge/noarch    73%[+] 1.0s
# conda-forge/linux-64  35%
# conda-forge/noarch    84%[+] 1.1s
# conda-forge/linux-64  35%
# conda-forge/noarch    95%conda-forge/noarch
# [+] 1.2s
# conda-forge/linux-64  40%[+] 1.3s
# conda-forge/linux-64  54%[+] 1.4s
# conda-forge/linux-64  64%[+] 1.5s
# conda-forge/linux-64  83%[+] 1.6s
# conda-forge/linux-64  92%[+] 1.7s
# conda-forge/linux-64  97%conda-forge/linux-64
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - openmm==7.7.0
#    - pdbfixer
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package               Version  Build                Channel           Size
# ──────────────────────────────────────────────────────────────────────────────
#   Install:
# ──────────────────────────────────────────────────────────────────────────────
#
#   + libgfortran5         13.2.0  hca663fb_7           conda-forge        1MB
#   + cudatoolkit          11.8.0  h4ba93d1_13          conda-forge      716MB
#   + ocl-icd               2.3.2  hd590300_1           conda-forge      136kB
#   + libgfortran-ng       13.2.0  h69a702a_7           conda-forge       24kB
#   + ocl-icd-system        1.0.0  1                    conda-forge        4kB
#   + fftw                 3.3.10  nompi_hc118613_108   conda-forge        2MB
#   + libopenblas          0.3.27  pthreads_h413a1c8_0  conda-forge        6MB
#   + libblas               3.9.0  22_linux64_openblas  conda-forge       15kB
#   + libcblas              3.9.0  22_linux64_openblas  conda-forge       14kB
#   + liblapack             3.9.0  22_linux64_openblas  conda-forge       14kB
#   + numpy                1.26.4  py310hb13e2d6_0      conda-forge        7MB
#   + openmm                7.7.0  py310hccf1d78_1      conda-forge       12MB
#   + pdbfixer              1.8.1  pyh6c4a22f_0         conda-forge      510kB
#
#   Upgrade:
# ──────────────────────────────────────────────────────────────────────────────
#
#   - ca-certificates  2023.11.17  hbcca054_0           conda-forge     Cached
#   + ca-certificates    2024.2.2  hbcca054_0           conda-forge      155kB
#   - openssl               3.2.0  hd590300_1           conda-forge     Cached
#   + openssl               3.3.0  hd590300_0           conda-forge        3MB
#   - certifi          2023.11.17  pyhd8ed1ab_0         conda-forge     Cached
#   + certifi            2024.2.2  pyhd8ed1ab_0         conda-forge      161kB
#
#   Summary:
#
#   Install: 13 packages
#   Upgrade: 3 packages
#
#   Total download: 747MB
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading        0%
# Extracting         0%ocl-icd                                            135.7kB @   1.4MB/s  0.1s
# [+] 0.1s
# Downloading  (5)   1%
# Extracting   (1)  ⣾  ca-certificates                                    155.4kB @   1.4MB/s  0.1s
# libgfortran5                                         1.4MB @  11.3MB/s  0.1s
# libcblas                                            14.4kB @ 108.2kB/s  0.0s
# openssl                                              2.9MB @  18.2MB/s  0.2s
# libgfortran-ng                                      24.3kB @ 151.1kB/s  0.0s
# [+] 0.2s
# Downloading  (5)   2%
# Extracting   (4)  ⣾  certifi                                            160.6kB @ 759.9kB/s  0.1s
# [+] 0.3s
# Downloading  (5)   4%
# Extracting   (3)  ⣾  liblapack                                           14.5kB @  45.2kB/s  0.1s
# [+] 0.4s
# Downloading  (5)   5%
# Extracting   (4)  ⣾  libopenblas                                          5.6MB @  13.8MB/s  0.3s
# numpy                                                7.0MB @  17.2MB/s  0.2s
# ocl-icd-system                                       4.3kB @   9.3kB/s  0.0s
# libblas                                             14.5kB @  31.8kB/s  0.0s
# openmm                                              11.8MB @  24.5MB/s  0.4s
# fftw                                                 2.0MB @   4.2MB/s  0.1s
# [+] 0.5s
# Downloading  (2)   7%
# Extracting   (9)  ⣾  pdbfixer                                           510.4kB @ 953.4kB/s  0.1s
# [+] 0.6s
# Downloading  (1)   8%
# Extracting   (7)  ⣾  [+] 0.7s
# Downloading  (1)   9%
# Extracting   (6)  ⣾  [+] 0.8s
# Downloading  (1)  10%
# Extracting   (6)  ⣾  [+] 0.9s
# Downloading  (1)  11%
# Extracting   (5)  ⣾  [+] 1.0s
# Downloading  (1)  12%
# Extracting   (4)  ⣾  [+] 1.1s
# Downloading  (1)  13%
# Extracting   (4)  ⣾  [+] 1.2s
# Downloading  (1)  15%
# Extracting   (4)  ⣾  [+] 1.3s
# Downloading  (1)  17%
# Extracting   (4)  ⣾  [+] 1.4s
# Downloading  (1)  19%
# Extracting   (3)  ⣾  [+] 1.5s
# Downloading  (1)  22%
# Extracting   (1)  ⣾  [+] 1.6s
# Downloading  (1)  23%
# Extracting   (1)  ⣾  [+] 1.7s
# Downloading  (1)  26%
# Extracting   (1)  ⣾  [+] 1.8s
# Downloading  (1)  29%
# Extracting   (1)  ⣾  [+] 1.9s
# Downloading  (1)  33%
# Extracting   (1)  ⣾  [+] 2.0s
# Downloading  (1)  36%
# Extracting   (1)  ⣾  [+] 2.1s
# Downloading  (1)  40%
# Extracting   (1)  ⣾  [+] 2.2s
# Downloading  (1)  43%
# Extracting   (1)  ⣾  [+] 2.3s
# Downloading  (1)  46%
# Extracting   (1)  ⣾  [+] 2.4s
# Downloading  (1)  49%
# Extracting   (1)  ⣾  [+] 2.5s
# Downloading  (1)  51%
# Extracting   (1)  ⣾  [+] 2.6s
# Downloading  (1)  52%
# Extracting   (1)  ⣾  [+] 2.7s
# Downloading  (1)  55%
# Extracting   (1)  ⣾  [+] 2.8s
# Downloading  (1)  58%
# Extracting   (1)  ⣾  [+] 2.9s
# Downloading  (1)  60%
# Extracting   (1)  ⣾  [+] 3.0s
# Downloading  (1)  64%
# Extracting   (1)  ⣾  [+] 3.1s
# Downloading  (1)  68%
# Extracting   (1)  ⣾  [+] 3.2s
# Downloading  (1)  70%
# Extracting   (1)  ⣾  [+] 3.3s
# Downloading  (1)  73%
# Extracting   (1)  ⣾  [+] 3.4s
# Downloading  (1)  75%
# Extracting   (1)  ⣾  [+] 3.5s
# Downloading  (1)  78%
# Extracting   (1)  ⣾  [+] 3.6s
# Downloading  (1)  80%
# Extracting   (1)  ⣾  [+] 3.7s
# Downloading  (1)  82%
# Extracting   (1)  ⣾  [+] 3.8s
# Downloading  (1)  85%
# Extracting   (1)  ⣾  [+] 3.9s
# Downloading  (1)  88%
# Extracting   (1)  ⣾  [+] 4.0s
# Downloading  (1)  91%
# Extracting   (1)  ⣾  [+] 4.1s
# Downloading  (1)  95%
# Extracting   (1)  ⣾  [+] 4.2s
# Downloading  (1)  98%
# Extracting   (1)  ⣾  cudatoolkit                                        715.6MB @ 167.2MB/s  4.3s
# [+] 4.3s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 4.4s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 4.5s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 4.6s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 4.7s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 4.8s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 4.9s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 5.0s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 5.1s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 5.2s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 5.3s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 5.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 5.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 6.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 6.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 6.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 6.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 6.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 6.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 6.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 6.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 6.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 6.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 7.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 7.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 7.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 7.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 7.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 7.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 7.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 7.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 7.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 7.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 8.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 8.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 8.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 8.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 8.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 8.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 8.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 8.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 8.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 8.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 9.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 10.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 12.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 12.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 12.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 12.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 12.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 12.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 12.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 12.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 12.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 12.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.3s
# Downloading      100%
# Extracting       100%
# Downloading and Extracting Packages:
#
# done
# done
# - By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html
#
# done

# %%
#@title Functions
from alphafold.relax import relax
from alphafold.relax import utils
from alphafold.common import protein as p_cf

from colabdesign.af.alphafold.common import protein
from colabdesign.shared.protein import renum_pdb_str
from colabdesign.af.alphafold.common import residue_constants

import pdbfixer
import numpy as np
import jax

def rank_array(input_array):
    # numpy.argsort returns the indices that would sort an array.
    # We convert it to a python list before returning
    return list(np.argsort(input_array))

def rank_and_write_pdb(af_model, name, write_all=False, renum_pdb = True):

    ranking = rank_array(af_model.aux['all']['loss'])
    if write_all != True:
        ranking = [ranking[0]]

    aux = af_model._tmp["best"]["aux"]
    aux = aux["all"]

    p = {k:aux[k] for k in ["aatype","residue_index","atom_positions","atom_mask"]}
    p["b_factors"] = 100 * p["atom_mask"] * aux["plddt"][...,None]

    def to_pdb_str(x, n=None):
        p_str = protein.to_pdb(protein.Protein(**x))
        p_str = "\n".join(p_str.splitlines()[1:-2])
        if renum_pdb: p_str = renum_pdb_str(p_str, af_model._lengths)
        if n is not None:
            p_str = f"MODEL{n:8}\n{p_str}\nENDMDL\n"
        return p_str

    m=1
    for n in ranking:
        p_str = ""
        p_str += to_pdb_str(jax.tree_map(lambda x:x[n],p), n+1)
        p_str += "END\n"

        with open(name + '_model_{n}_rank_{m}.pdb'.format(n=n, m=m), 'w') as f:
            f.write(p_str)
        m+=1

MODRES = {'MSE':'MET','MLY':'LYS','FME':'MET','HYP':'PRO',
          'TPO':'THR','CSO':'CYS','SEP':'SER','M3L':'LYS',
          'HSK':'HIS','SAC':'SER','PCA':'GLU','DAL':'ALA',
          'CME':'CYS','CSD':'CYS','OCS':'CYS','DPR':'PRO',
          'B3K':'LYS','ALY':'LYS','YCM':'CYS','MLZ':'LYS',
          '4BF':'TYR','KCX':'LYS','B3E':'GLU','B3D':'ASP',
          'HZP':'PRO','CSX':'CYS','BAL':'ALA','HIC':'HIS',
          'DBZ':'ALA','DCY':'CYS','DVA':'VAL','NLE':'LEU',
          'SMC':'CYS','AGM':'ARG','B3A':'ALA','DAS':'ASP',
          'DLY':'LYS','DSN':'SER','DTH':'THR','GL3':'GLY',
          'HY3':'PRO','LLP':'LYS','MGN':'GLN','MHS':'HIS',
          'TRQ':'TRP','B3Y':'TYR','PHI':'PHE','PTR':'TYR',
          'TYS':'TYR','IAS':'ASP','GPL':'LYS','KYN':'TRP',
          'CSD':'CYS','SEC':'CYS'}

def pdb_to_string(pdb_file, chains=None, models=[1]):
  '''read pdb file and return as string'''

  if chains is not None:
    if "," in chains: chains = chains.split(",")
    if not isinstance(chains,list): chains = [chains]
  if models is not None:
    if not isinstance(models,list): models = [models]

  modres = {**MODRES}
  lines = []
  seen = []
  model = 1
  for line in open(pdb_file,"rb"):
    line = line.decode("utf-8","ignore").rstrip()
    if line[:5] == "MODEL":
      model = int(line[5:])
    if models is None or model in models:
      if line[:6] == "MODRES":
        k = line[12:15]
        v = line[24:27]
        if k not in modres and v in residue_constants.restype_3to1:
          modres[k] = v
      if line[:6] == "HETATM":
        k = line[17:20]
        if k in modres:
          line = "ATOM  "+line[6:17]+modres[k]+line[20:]
      if line[:4] == "ATOM":
        chain = line[21:22]
        if chains is None or chain in chains:
          atom = line[12:12+4].strip()
          resi = line[17:17+3]
          resn = line[22:22+5].strip()
          if resn[-1].isalpha(): # alternative atom
            resn = resn[:-1]
            line = line[:26]+" "+line[27:]
          key = f"{model}_{chain}_{resn}_{resi}_{atom}"
          if key not in seen: # skip alternative placements
            lines.append(line)
            seen.append(key)
      if line[:5] == "MODEL" or line[:3] == "TER" or line[:6] == "ENDMDL":
        lines.append(line)
  return "\n".join(lines)

def relax_me(pdb_in, pdb_out):
  pdb_str = pdb_to_string(pdb_in)
  protein_obj = p_cf.from_pdb_string(pdb_str)
  amber_relaxer = relax.AmberRelaxation(
    max_iterations=0,
    tolerance=2.39,
    stiffness=10.0,
    exclude_residues=[],
    max_outer_iterations=3,
    use_gpu=False)
  relaxed_pdb_lines, _, _ = amber_relaxer.process(prot=protein_obj)
  with open(pdb_out, 'w') as f:
      f.write(relaxed_pdb_lines)


def rank_array_predict(input_array):
    # numpy.argsort returns the indices that would sort an array.
    # We convert it to a python list before returning
    return list(np.argsort(input_array))[::-1]

def rank_and_write_pdb_predict(af_model, name, write_all=False, renum_pdb = True):
    ranking = rank_array_predict(np.mean(af_model.aux['all']['plddt'],-1))
    if write_all != True:
        ranking = [ranking[0]]

    aux = af_model.aux
    aux = aux["all"]

    p = {k:aux[k] for k in ["aatype","residue_index","atom_positions","atom_mask"]}
    p["b_factors"] = 100 * p["atom_mask"] * aux["plddt"][...,None]

    def to_pdb_str(x, n=None):
        p_str = protein.to_pdb(protein.Protein(**x))
        p_str = "\n".join(p_str.splitlines()[1:-2])
        if renum_pdb: p_str = renum_pdb_str(p_str, af_model._lengths)
        #if n is not None:
        #    p_str = f"MODEL{n:8}\n{p_str}\nENDMDL\n"
        return p_str

    m=1

    pdbs_out = []

    for n in ranking:
        p_str = ""
        p_str += to_pdb_str(jax.tree_map(lambda x:x[n],p), n+1)
        p_str += "END\n"

        with open(name + '_model_{n}_rank_{m}.pdb'.format(n=n, m=m), 'w') as f:
            f.write(p_str)
        pdbs_out.append(name + '_model_{n}_rank_{m}.pdb'.format(n=n, m=m))
        m+=1
    return pdbs_out


aa_order = residue_constants.restype_order
order_aa = {b:a for a,b in aa_order.items()}

def get_best_seq(aux):
    x = aux["seq"]["hard"].argmax(-1)
    return ["".join([order_aa[a] for a in s]) for s in x]

# %%
#@title Relaxation
import jax
import jax.numpy as jnp
import os

from colabdesign import mk_afdesign_model

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pickle
from tqdm.notebook import tqdm
import glob

from colabdesign.af.alphafold.common import protein
from colabdesign.shared.protein import renum_pdb_str
from colabdesign.af.alphafold.common import residue_constants

target_pdb = 'glp1_inactive.pdb' #@param {type:"string"}
target_chain ='A' #@param {type:"string"}
design_length = 20  #@param {type:"integer"}
sequences = 'AEPRYLLYQFIRYLSRFEDW,EARWYLYQFMRWLSYMEDAA,MNYRAAWQVMFRMDFDLYEE'#@param {type:"string"}

results_directory = 'results_dir' #@param {type:"string"}
os.system(f'mkdir {results_directory}/relaxed')

af_model = mk_afdesign_model(protocol="binder",
                             use_templates=True)
af_model.prep_inputs(pdb_filename=target_pdb,
                     chain=target_chain,
                     binder_len=design_length,
                     rm_aa='C')

af_model.set_opt("con",num=2)
af_model.set_opt("i_con",num=1)
af_model.opt["weights"]["plddt"] = 0.1
af_model.opt["weights"]["fape"] = 1.0

# load all sequences, remove duplicates
sequences = sequences.split(',')
names = []

for i,x in enumerate(sequences):
  seq = x
  name = f'design_{i}'
  print('Predicting:', name, seq)
  af_model.set_seq(seq)
  af_model.predict(num_recycles=3)
  pdbs = rank_and_write_pdb_predict(af_model, name= f'{results_directory}/relaxed/'+name)
  print('Relaxing...')
  for pdb in pdbs:
    pdb_out = pdb.split('.pdb')[0] + '_relaxed.pdb'
    relax_me(pdb, pdb_out)
    os.remove(pdb) # delete unrelaxed pdb file
# Out:
# Predicting: design_0 AEPRYLLYQFIRYLSRFEDW
# predict models [0] recycles 3 hard 1 soft 0 temp 1 loss 3.65 i_con 3.59 plddt 0.43 ptm 0.69 i_ptm 0.35
# Relaxing...
# <ipython-input-2-fcaffe1730a5>:153: DeprecationWarning: jax.tree_map is deprecated: use jax.tree.map (jax v0.4.25 or newer) or jax.tree_util.tree_map (any JAX version).
#   p_str += to_pdb_str(jax.tree_map(lambda x:x[n],p), n+1)
# Warning: importing 'simtk.openmm' is deprecated.  Import 'openmm' instead.
# Predicting: design_1 EARWYLYQFMRWLSYMEDAA
# predict models [0] recycles 3 hard 1 soft 0 temp 1 loss 3.67 i_con 3.61 plddt 0.42 ptm 0.69 i_ptm 0.34
# Relaxing...
# <ipython-input-2-fcaffe1730a5>:153: DeprecationWarning: jax.tree_map is deprecated: use jax.tree.map (jax v0.4.25 or newer) or jax.tree_util.tree_map (any JAX version).
#   p_str += to_pdb_str(jax.tree_map(lambda x:x[n],p), n+1)
# Predicting: design_2 MNYRAAWQVMFRMDFDLYEE
# predict models [0] recycles 3 hard 1 soft 0 temp 1 loss 3.19 i_con 3.15 plddt 0.56 ptm 0.69 i_ptm 0.56
# Relaxing...
# <ipython-input-2-fcaffe1730a5>:153: DeprecationWarning: jax.tree_map is deprecated: use jax.tree.map (jax v0.4.25 or newer) or jax.tree_util.tree_map (any JAX version).
#   p_str += to_pdb_str(jax.tree_map(lambda x:x[n],p), n+1)

# %%
from colabdesign.mpnn import mk_mpnn_model
import glob

chain_to_design = 'B' #@param {type:"string"}
chain_length = 20 #@param {type:"integer"}
design_pos = ','.join([f'{chain_to_design}{i+1}' for i in range(chain_length)])
number_of_seqs = 5 #@param {type:"integer"}
model_name = "v_48_010"

os.system(f'mkdir {results_directory}/mpnn')
for i in glob.glob(f'{results_directory}/relaxed/*.pdb'):
  mpnn_model = mk_mpnn_model(model_name, backbone_noise=0.0)
  mpnn_model.prep_inputs(pdb_filename=i, chain='A,B', fix_pos=design_pos, rm_aa = "C", inverse=True)

  samples = mpnn_model.sample_parallel(temperature=0.2, batch=number_of_seqs)
  name = i.split('/')[-1].split('.pdb')[0]
  with open(f'{results_directory}/mpnn/{name}.pickle', 'wb') as handle:
      pickle.dump(samples, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
#@title Read sequences from ProteinMPNN
sequences = []
names = []

for file in glob.glob(f'{results_directory}/mpnn/*.pickle'):
    name = file.split('.pickle')[0].split('/')[-1]
    with open(file, 'rb') as f:
        x = pickle.load(f)
    n = 0
    for seq in x['seq']:
        if seq not in sequences:
            sequences.append(seq[-20:])
            names.append('{name}_{n}'.format(name=name, n=n))
            n += 1
        else:
            print('duplicate found!')

# %%
print(sequences)
# Out:
# ['LPEQLLKYFLRSFHHFSTTF', 'LPEQILKYFLRYFSHFSTSF', 'MPEQLLKYYLRFFSHFGTAF', 'LEEQILKYYLRFFGHFGTIF', 'LPEQLLKYYIRFFSHFSTAF', 'LLPKQALHLMLKLFFSRFIR', 'RLPQEALHLLTKLFFDRFRK', 'RLPKQALHLLLKLFFSRFIP', 'MLPKQALHSMLKLFFDRFLP', 'MSPQQALHLMFKLDGDRFLK', 'VPPSTLAYIVVRLLAKGLLL', 'VPPSLLAYIAVQDLLKFLKR', 'VPPSLLAYVAVRGLLKGLRL', 'IPPSTLAFYAVKSLAKFLDY', 'VPPSTLTYYAVQSLLKLLTR']

# %%
#@title Predict sequences from ProteinMPNN

os.system(f'mkdir {results_directory}/mpnn/pdb')
af_model = mk_afdesign_model(protocol="binder",
                             use_templates=True)
af_model.prep_inputs(pdb_filename=target_pdb,
                     chain=target_chain,
                     binder_len=design_length,
                     rm_aa='C')

for i,x in enumerate(sequences):
  seq = sequences[i]
  name = names[i]
  print('Predicting:', name, seq)
  af_model.set_seq(seq)
  af_model.predict(num_recycles=3)

  pdbs = rank_and_write_pdb_predict(af_model, name=f'{results_directory}/mpnn/pdb/' + name)
  '''
  print('Relaxing...')
  for pdb in pdbs:
    pdb_out = pdb.split('.pdb')[0] + '_relaxed.pdb'
    relax_me(pdb, pdb_out)
    os.remove(pdb) # delete unrelaxed pdb file
  '''
  with open(f'{results_directory}/mpnn/pdb/{name}.pickle'.format(name=name), 'wb') as handle:
    pickle.dump(af_model.aux['all'], handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Predicting: design_1_model_0_rank_1_relaxed_0 LPEQLLKYFLRSFHHFSTTF
# predict models [0] recycles 3 hard 1 soft 0 temp 1 loss 3.55 i_con 3.50 plddt 0.48 ptm 0.67 i_ptm 0.39
# Predicting: design_1_model_0_rank_1_relaxed_1 LPEQILKYFLRYFSHFSTSF
# <ipython-input-2-fcaffe1730a5>:153: DeprecationWarning: jax.tree_map is deprecated: use jax.tree.map (jax v0.4.25 or newer) or jax.tree_util.tree_map (any JAX version).
#   p_str += to_pdb_str(jax.tree_map(lambda x:x[n],p), n+1)
# predict models [0] recycles 3 hard 1 soft 0 temp 1 loss 3.48 i_con 3.43 plddt 0.50 ptm 0.69 i_ptm 0.44
# Predicting: design_1_model_0_rank_1_relaxed_2 MPEQLLKYYLRFFSHFGTAF
# predict models [0] recycles 3 hard 1 soft 0 temp 1 loss 3.24 i_con 3.20 plddt 0.57 ptm 0.70 i_ptm 0.53
# Predicting: design_1_model_0_rank_1_relaxed_3 LEEQILKYYLRFFGHFGTIF
# predict models [0] recycles 3 hard 1 soft 0 temp 1 loss 3.29 i_con 3.25 plddt 0.55 ptm 0.70 i_ptm 0.51
# Predicting: design_1_model_0_rank_1_relaxed_4 LPEQLLKYYIRFFSHFSTAF
# predict models [0] recycles 3 hard 1 soft 0 temp 1 loss 3.28 i_con 3.24 plddt 0.55 ptm 0.70 i_ptm 0.51
# Predicting: design_2_model_0_rank_1_relaxed_0 LLPKQALHLMLKLFFSRFIR
# predict models [0] recycles 3 hard 1 soft 0 temp 1 loss 4.63 i_con 4.60 plddt 0.63 ptm 0.69 i_ptm 0.13
# Predicting: design_2_model_0_rank_1_relaxed_1 RLPQEALHLLTKLFFDRFRK
# predict models [0] recycles 3 hard 1 soft 0 temp 1 loss 3.91 i_con 3.85 plddt 0.45 ptm 0.69 i_ptm 0.28
# Predicting: design_2_model_0_rank_1_relaxed_2 RLPKQALHLLLKLFFSRFIP
# predict models [0] recycles 3 hard 1 soft 0 temp 1 loss 5.02 i_con 4.99 plddt 0.70 ptm 0.70 i_ptm 0.16
# Predicting: design_2_model_0_rank_1_relaxed_3 MLPKQALHSMLKLFFDRFLP
# predict models [0] recycles 3 hard 1 soft 0 temp 1 loss 3.87 i_con 3.82 plddt 0.45 ptm 0.68 i_ptm 0.26
# Predicting: design_2_model_0_rank_1_relaxed_4 MSPQQALHLMFKLDGDRFLK
# predict models [0] recycles 3 hard 1 soft 0 temp 1 loss 3.88 i_con 3.82 plddt 0.45 ptm 0.67 i_ptm 0.28
# Predicting: design_0_model_0_rank_1_relaxed_0 VPPSTLAYIVVRLLAKGLLL
# predict models [0] recycles 3 hard 1 soft 0 temp 1 loss 4.89 i_con 4.86 plddt 0.68 ptm 0.70 i_ptm 0.12
# Predicting: design_0_model_0_rank_1_relaxed_1 VPPSLLAYIAVQDLLKFLKR
# predict models [0] recycles 3 hard 1 soft 0 temp 1 loss 3.65 i_con 3.60 plddt 0.54 ptm 0.69 i_ptm 0.38
# Predicting: design_0_model_0_rank_1_relaxed_2 VPPSLLAYVAVRGLLKGLRL
# predict models [0] recycles 3 hard 1 soft 0 temp 1 loss 3.90 i_con 3.85 plddt 0.52 ptm 0.69 i_ptm 0.33
# Predicting: design_0_model_0_rank_1_relaxed_3 IPPSTLAFYAVKSLAKFLDY
# predict models [0] recycles 3 hard 1 soft 0 temp 1 loss 2.95 i_con 2.92 plddt 0.67 ptm 0.70 i_ptm 0.63
# Predicting: design_0_model_0_rank_1_relaxed_4 VPPSTLTYYAVQSLLKLLTR
# predict models [0] recycles 3 hard 1 soft 0 temp 1 loss 3.87 i_con 3.82 plddt 0.52 ptm 0.69 i_ptm 0.34

# %%
#@title Read scores
names = []
plddts = []
iptms = []

for file in glob.glob(f'{results_directory}/mpnn/pdb/*.pickle'):
    name = file.split('.pickle')[0].split('/')[-1]
    with open(file, 'rb') as f:
        x = pickle.load(f)
    n = 0
    names.append(name)
    plddts.append(np.mean(x['plddt'][0][-20:]))
    iptms.append(float(x['i_ptm'][0]))

# %%
#@title Save as table .csv
import pandas as pd
name_of_csv_file = 'my_results.csv' #@param {type:"string"}
df = {'name': names,
      'plddts':plddts,
      'i_ptm': iptms}
df = pd.DataFrame(df)
df.to_csv('my_results.csv')
